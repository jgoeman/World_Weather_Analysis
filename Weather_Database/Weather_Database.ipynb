# %%
import pandas as pd
from citipy import citipy
from config import weather_api_key
import requests
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90,90, 2000)
lngs = np.random.uniform(-180,180, 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Turn the lat_lngs zip inter an interable list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates :
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count.
len(cities)
# Out:
# 764

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data
city_data = []
#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_weather = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_weather}) 
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | grindavik
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 8 of Set 1 | grafton
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | cayenne
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | coihaique
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | nanortalik
# Processing Record 19 of Set 1 | sarangani
# Processing Record 20 of Set 1 | ranong
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | angra
# City not found. Skipping...
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | wajima
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | lewisporte
# Processing Record 29 of Set 1 | sosnovo-ozerskoye
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | san carlos del zulia
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | mehamn
# Processing Record 35 of Set 1 | yerbogachen
# Processing Record 36 of Set 1 | trairi
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | sestu
# Processing Record 39 of Set 1 | tinton falls
# Processing Record 40 of Set 1 | jadu
# Processing Record 41 of Set 1 | ulladulla
# Processing Record 42 of Set 1 | narsaq
# Processing Record 43 of Set 1 | yichun
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | katherine
# Processing Record 46 of Set 1 | elat
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 2 | paita
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | dalbandin
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | nouakchott
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | rudnogorsk
# Processing Record 9 of Set 2 | hamilton
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | luwuk
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | ibra
# Processing Record 15 of Set 2 | oktyabrskiy
# Processing Record 16 of Set 2 | ushtobe
# Processing Record 17 of Set 2 | aracruz
# Processing Record 18 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | rikitea
# Processing Record 21 of Set 2 | port hardy
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | sovetskiy
# Processing Record 25 of Set 2 | oppdal
# Processing Record 26 of Set 2 | neya
# Processing Record 27 of Set 2 | souillac
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | maragogi
# Processing Record 30 of Set 2 | novoagansk
# Processing Record 31 of Set 2 | puro
# Processing Record 32 of Set 2 | turukhansk
# Processing Record 33 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 2 | tuensang
# Processing Record 35 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 2 | ocean city
# Processing Record 37 of Set 2 | kolaras
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | kidal
# Processing Record 40 of Set 2 | ligayan
# Processing Record 41 of Set 2 | san felipe
# Processing Record 42 of Set 2 | dudinka
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | atasu
# Processing Record 46 of Set 2 | hambantota
# Processing Record 47 of Set 2 | omsukchan
# Processing Record 48 of Set 2 | bathsheba
# Processing Record 49 of Set 2 | tilichiki
# Processing Record 50 of Set 2 | santa maria
# Processing Record 1 of Set 3 | severo-kurilsk
# Processing Record 2 of Set 3 | shimanovsk
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | khovu-aksy
# Processing Record 5 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 6 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 3 | okakarara
# Processing Record 8 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 9 of Set 3 | sao gabriel da cachoeira
# Processing Record 10 of Set 3 | sao sebastiao
# Processing Record 11 of Set 3 | atar
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | sanary-sur-mer
# Processing Record 15 of Set 3 | stepanov
# Processing Record 16 of Set 3 | crystal beach
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | honiara
# Processing Record 19 of Set 3 | broken hill
# Processing Record 20 of Set 3 | hitchin
# Processing Record 21 of Set 3 | yar-sale
# Processing Record 22 of Set 3 | bonavista
# Processing Record 23 of Set 3 | hermanus
# Processing Record 24 of Set 3 | misratah
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | makakilo city
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | naze
# Processing Record 32 of Set 3 | lavrentiya
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | seoul
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | lufkin
# Processing Record 37 of Set 3 | palu
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | kayes
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | teahupoo
# Processing Record 42 of Set 3 | corinto
# Processing Record 43 of Set 3 | saint-augustin
# Processing Record 44 of Set 3 | tyup
# Processing Record 45 of Set 3 | butaritari
# Processing Record 46 of Set 3 | geraldton
# Processing Record 47 of Set 3 | tooele
# Processing Record 48 of Set 3 | nauen
# Processing Record 49 of Set 3 | faanui
# Processing Record 50 of Set 3 | hami
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | ust-shonosha
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | bochnia
# Processing Record 5 of Set 4 | sobolevo
# Processing Record 6 of Set 4 | muros
# Processing Record 7 of Set 4 | ponazyrevo
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | birjand
# Processing Record 10 of Set 4 | pouembout
# Processing Record 11 of Set 4 | burley
# Processing Record 12 of Set 4 | neuquen
# Processing Record 13 of Set 4 | danilovka
# Processing Record 14 of Set 4 | kibaya
# Processing Record 15 of Set 4 | codrington
# Processing Record 16 of Set 4 | sulangan
# Processing Record 17 of Set 4 | rodrigues alves
# Processing Record 18 of Set 4 | krasnoselkup
# Processing Record 19 of Set 4 | moyale
# Processing Record 20 of Set 4 | dunedin
# Processing Record 21 of Set 4 | dingle
# Processing Record 22 of Set 4 | vanavara
# Processing Record 23 of Set 4 | kawalu
# Processing Record 24 of Set 4 | solenzo
# Processing Record 25 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 26 of Set 4 | zhongshu
# Processing Record 27 of Set 4 | sofiysk
# City not found. Skipping...
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | dargaville
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | kangaatsiaq
# Processing Record 32 of Set 4 | the valley
# Processing Record 33 of Set 4 | buala
# Processing Record 34 of Set 4 | akdepe
# Processing Record 35 of Set 4 | asau
# Processing Record 36 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 4 | mangan
# Processing Record 38 of Set 4 | umarkot
# Processing Record 39 of Set 4 | nemuro
# Processing Record 40 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 41 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 4 | elizabeth city
# Processing Record 43 of Set 4 | bilibino
# Processing Record 44 of Set 4 | flinders
# Processing Record 45 of Set 4 | genhe
# Processing Record 46 of Set 4 | kouroussa
# Processing Record 47 of Set 4 | magistralnyy
# Processing Record 48 of Set 4 | yulara
# Processing Record 49 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 4 | atuona
# Processing Record 1 of Set 5 | ransang
# Processing Record 2 of Set 5 | agra
# Processing Record 3 of Set 5 | fairmont
# Processing Record 4 of Set 5 | tarakan
# Processing Record 5 of Set 5 | tsogni
# Processing Record 6 of Set 5 | klaksvik
# Processing Record 7 of Set 5 | brae
# Processing Record 8 of Set 5 | torit
# Processing Record 9 of Set 5 | soyo
# Processing Record 10 of Set 5 | matagami
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | walvis bay
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | chicama
# Processing Record 15 of Set 5 | lazaro cardenas
# Processing Record 16 of Set 5 | leona vicario
# Processing Record 17 of Set 5 | northam
# Processing Record 18 of Set 5 | plattsburgh
# Processing Record 19 of Set 5 | isangel
# Processing Record 20 of Set 5 | arraial do cabo
# Processing Record 21 of Set 5 | la asuncion
# Processing Record 22 of Set 5 | slonim
# Processing Record 23 of Set 5 | turayf
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | karratha
# Processing Record 26 of Set 5 | margate
# Processing Record 27 of Set 5 | kieta
# Processing Record 28 of Set 5 | palana
# Processing Record 29 of Set 5 | alice springs
# Processing Record 30 of Set 5 | new norfolk
# Processing Record 31 of Set 5 | upernavik
# Processing Record 32 of Set 5 | hasaki
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | provideniya
# Processing Record 35 of Set 5 | saint-philippe
# Processing Record 36 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 5 | pisco
# Processing Record 38 of Set 5 | alta floresta
# Processing Record 39 of Set 5 | san juan
# Processing Record 40 of Set 5 | tevaitoa
# Processing Record 41 of Set 5 | tombouctou
# Processing Record 42 of Set 5 | hurghada
# Processing Record 43 of Set 5 | thabazimbi
# Processing Record 44 of Set 5 | samarai
# Processing Record 45 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 5 | quang ngai
# Processing Record 47 of Set 5 | visnes
# Processing Record 48 of Set 5 | belyy yar
# Processing Record 49 of Set 5 | bac
# Processing Record 50 of Set 5 | tiksi
# Processing Record 1 of Set 6 | constantine
# Processing Record 2 of Set 6 | namibe
# Processing Record 3 of Set 6 | ust-ilimsk
# Processing Record 4 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 6 | gewane
# Processing Record 6 of Set 6 | victor harbor
# Processing Record 7 of Set 6 | paka
# Processing Record 8 of Set 6 | merauke
# Processing Record 9 of Set 6 | caucaia
# Processing Record 10 of Set 6 | ribeira grande
# Processing Record 11 of Set 6 | abnub
# Processing Record 12 of Set 6 | muzhi
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 6 | araouane
# Processing Record 16 of Set 6 | sao joao da barra
# Processing Record 17 of Set 6 | kirkwall
# Processing Record 18 of Set 6 | kamra
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | fortuna
# Processing Record 21 of Set 6 | otradnoye
# Processing Record 22 of Set 6 | urumqi
# Processing Record 23 of Set 6 | porto walter
# Processing Record 24 of Set 6 | jiwani
# Processing Record 25 of Set 6 | saint-joseph
# Processing Record 26 of Set 6 | pangnirtung
# Processing Record 27 of Set 6 | san andres
# Processing Record 28 of Set 6 | vardo
# Processing Record 29 of Set 6 | abucay
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | nushki
# Processing Record 32 of Set 6 | mpulungu
# Processing Record 33 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 6 | along
# Processing Record 35 of Set 6 | huaihua
# Processing Record 36 of Set 6 | ancud
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | sitka
# Processing Record 39 of Set 6 | lokosovo
# Processing Record 40 of Set 6 | zhitikara
# City not found. Skipping...
# Processing Record 41 of Set 6 | axim
# Processing Record 42 of Set 6 | awjilah
# Processing Record 43 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 6 | ponta do sol
# Processing Record 45 of Set 6 | jaypur
# Processing Record 46 of Set 6 | tambopata
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | batagay
# Processing Record 49 of Set 6 | wanlaweyn
# Processing Record 50 of Set 6 | sur
# Processing Record 1 of Set 7 | zhigansk
# Processing Record 2 of Set 7 | laguna
# Processing Record 3 of Set 7 | ambilobe
# Processing Record 4 of Set 7 | bandundu
# Processing Record 5 of Set 7 | yellowknife
# Processing Record 6 of Set 7 | lalomanu
# City not found. Skipping...
# Processing Record 7 of Set 7 | kavieng
# Processing Record 8 of Set 7 | keflavik
# Processing Record 9 of Set 7 | ouargaye
# Processing Record 10 of Set 7 | charters towers
# Processing Record 11 of Set 7 | ingham
# Processing Record 12 of Set 7 | yeppoon
# Processing Record 13 of Set 7 | comodoro rivadavia
# Processing Record 14 of Set 7 | torbay
# Processing Record 15 of Set 7 | iqaluit
# Processing Record 16 of Set 7 | jeremoabo
# Processing Record 17 of Set 7 | deep river
# Processing Record 18 of Set 7 | kaitangata
# Processing Record 19 of Set 7 | koster
# Processing Record 20 of Set 7 | khadyzhensk
# Processing Record 21 of Set 7 | los llanos de aridane
# Processing Record 22 of Set 7 | kouango
# Processing Record 23 of Set 7 | kungurtug
# Processing Record 24 of Set 7 | saint george
# Processing Record 25 of Set 7 | tasiilaq
# Processing Record 26 of Set 7 | broome
# Processing Record 27 of Set 7 | tuatapere
# Processing Record 28 of Set 7 | sao jose da coroa grande
# Processing Record 29 of Set 7 | novouzensk
# Processing Record 30 of Set 7 | pavlovka
# Processing Record 31 of Set 7 | mayo
# Processing Record 32 of Set 7 | umm kaddadah
# Processing Record 33 of Set 7 | vogar
# Processing Record 34 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 35 of Set 7 | laredo
# Processing Record 36 of Set 7 | umm lajj
# Processing Record 37 of Set 7 | mutoko
# Processing Record 38 of Set 7 | ileza
# Processing Record 39 of Set 7 | nabire
# Processing Record 40 of Set 7 | nioro
# Processing Record 41 of Set 7 | knysna
# Processing Record 42 of Set 7 | kruisfontein
# Processing Record 43 of Set 7 | namatanai
# Processing Record 44 of Set 7 | fethiye
# Processing Record 45 of Set 7 | soure
# Processing Record 46 of Set 7 | lucapa
# Processing Record 47 of Set 7 | belaya gora
# Processing Record 48 of Set 7 | mitsamiouli
# Processing Record 49 of Set 7 | fort nelson
# Processing Record 50 of Set 7 | tartus
# Processing Record 1 of Set 8 | havoysund
# Processing Record 2 of Set 8 | vestmannaeyjar
# Processing Record 3 of Set 8 | skjervoy
# Processing Record 4 of Set 8 | chirongui
# Processing Record 5 of Set 8 | arlit
# Processing Record 6 of Set 8 | leh
# Processing Record 7 of Set 8 | kismayo
# Processing Record 8 of Set 8 | coxim
# Processing Record 9 of Set 8 | beya
# Processing Record 10 of Set 8 | salalah
# Processing Record 11 of Set 8 | mount isa
# Processing Record 12 of Set 8 | oktyabrskoye
# Processing Record 13 of Set 8 | west bay
# Processing Record 14 of Set 8 | mount gambier
# Processing Record 15 of Set 8 | odweyne
# Processing Record 16 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 8 | sacramento
# Processing Record 18 of Set 8 | plettenberg bay
# Processing Record 19 of Set 8 | tukrah
# Processing Record 20 of Set 8 | camacha
# Processing Record 21 of Set 8 | kemijarvi
# Processing Record 22 of Set 8 | katsuura
# Processing Record 23 of Set 8 | vila velha
# Processing Record 24 of Set 8 | namie
# Processing Record 25 of Set 8 | san ramon
# Processing Record 26 of Set 8 | grand gaube
# Processing Record 27 of Set 8 | lyskovo
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | mwense
# Processing Record 30 of Set 8 | ketchikan
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | devonport
# Processing Record 33 of Set 8 | ulaangom
# Processing Record 34 of Set 8 | uroteppa
# City not found. Skipping...
# Processing Record 35 of Set 8 | yumen
# Processing Record 36 of Set 8 | manzil salim
# Processing Record 37 of Set 8 | ambulu
# Processing Record 38 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 8 | dhidhdhoo
# Processing Record 40 of Set 8 | puerto asis
# Processing Record 41 of Set 8 | caravelas
# Processing Record 42 of Set 8 | oneonta
# Processing Record 43 of Set 8 | vestmanna
# Processing Record 44 of Set 8 | nova russas
# Processing Record 45 of Set 8 | olafsvik
# Processing Record 46 of Set 8 | mana
# Processing Record 47 of Set 8 | el alto
# Processing Record 48 of Set 8 | vanino
# Processing Record 49 of Set 8 | kastamonu
# Processing Record 50 of Set 8 | tahe
# Processing Record 1 of Set 9 | palauig
# Processing Record 2 of Set 9 | moron
# Processing Record 3 of Set 9 | dzilam gonzalez
# Processing Record 4 of Set 9 | maniitsoq
# Processing Record 5 of Set 9 | tessalit
# Processing Record 6 of Set 9 | beipiao
# Processing Record 7 of Set 9 | newtownards
# Processing Record 8 of Set 9 | komsomolskiy
# Processing Record 9 of Set 9 | nola
# Processing Record 10 of Set 9 | tacuarembo
# Processing Record 11 of Set 9 | kaliua
# Processing Record 12 of Set 9 | la ronge
# Processing Record 13 of Set 9 | cap malheureux
# Processing Record 14 of Set 9 | norman wells
# Processing Record 15 of Set 9 | north branch
# Processing Record 16 of Set 9 | beringovskiy
# Processing Record 17 of Set 9 | helong
# Processing Record 18 of Set 9 | pombas
# Processing Record 19 of Set 9 | valparaiso
# Processing Record 20 of Set 9 | luangwa
# Processing Record 21 of Set 9 | kalmunai
# Processing Record 22 of Set 9 | pukhrayan
# Processing Record 23 of Set 9 | arkhangelskoye
# Processing Record 24 of Set 9 | inuvik
# Processing Record 25 of Set 9 | lago da pedra
# Processing Record 26 of Set 9 | cabo san lucas
# Processing Record 27 of Set 9 | chapais
# Processing Record 28 of Set 9 | konstantinovskoye
# Processing Record 29 of Set 9 | novyy urengoy
# Processing Record 30 of Set 9 | srednekolymsk
# Processing Record 31 of Set 9 | kelo
# Processing Record 32 of Set 9 | urucara
# Processing Record 33 of Set 9 | cadillac
# Processing Record 34 of Set 9 | hammerfest
# Processing Record 35 of Set 9 | dicabisagan
# Processing Record 36 of Set 9 | phalaborwa
# Processing Record 37 of Set 9 | waitara
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | ola
# Processing Record 40 of Set 9 | antofagasta
# Processing Record 41 of Set 9 | alenquer
# Processing Record 42 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 43 of Set 9 | port hedland
# Processing Record 44 of Set 9 | portland
# Processing Record 45 of Set 9 | lubuagan
# Processing Record 46 of Set 9 | veraval
# Processing Record 47 of Set 9 | muroto
# Processing Record 48 of Set 9 | nacala
# Processing Record 49 of Set 9 | puerto baquerizo moreno
# Processing Record 50 of Set 9 | nador
# Processing Record 1 of Set 10 | mocuba
# Processing Record 2 of Set 10 | pytalovo
# Processing Record 3 of Set 10 | santa cruz cabralia
# Processing Record 4 of Set 10 | stokmarknes
# Processing Record 5 of Set 10 | bataipora
# Processing Record 6 of Set 10 | nikitinskiy
# Processing Record 7 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 10 | botro
# Processing Record 9 of Set 10 | gouyave
# Processing Record 10 of Set 10 | igbo ora
# Processing Record 11 of Set 10 | hare bay
# Processing Record 12 of Set 10 | airai
# Processing Record 13 of Set 10 | yubari
# Processing Record 14 of Set 10 | padang
# Processing Record 15 of Set 10 | choix
# Processing Record 16 of Set 10 | villa vazquez
# City not found. Skipping...
# Processing Record 17 of Set 10 | bismil
# Processing Record 18 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 10 | puerto escondido
# Processing Record 20 of Set 10 | erzin
# Processing Record 21 of Set 10 | monte alegre
# Processing Record 22 of Set 10 | careiro da varzea
# Processing Record 23 of Set 10 | fare
# Processing Record 24 of Set 10 | akcaabat
# Processing Record 25 of Set 10 | maltahohe
# Processing Record 26 of Set 10 | zhuhai
# Processing Record 27 of Set 10 | hot springs
# Processing Record 28 of Set 10 | mahibadhoo
# Processing Record 29 of Set 10 | coquimbo
# Processing Record 30 of Set 10 | orikum
# Processing Record 31 of Set 10 | sao filipe
# Processing Record 32 of Set 10 | beruwala
# Processing Record 33 of Set 10 | ayr
# Processing Record 34 of Set 10 | sunndalsora
# Processing Record 35 of Set 10 | tete
# Processing Record 36 of Set 10 | mecca
# Processing Record 37 of Set 10 | havelock
# Processing Record 38 of Set 10 | karasjok
# Processing Record 39 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 40 of Set 10 | plaridel
# Processing Record 41 of Set 10 | adrar
# Processing Record 42 of Set 10 | yeehaw junction
# City not found. Skipping...
# Processing Record 43 of Set 10 | acapulco
# Processing Record 44 of Set 10 | george town
# Processing Record 45 of Set 10 | kulunda
# Processing Record 46 of Set 10 | leningradskiy
# Processing Record 47 of Set 10 | batangafo
# Processing Record 48 of Set 10 | westport
# Processing Record 49 of Set 10 | temple
# Processing Record 50 of Set 10 | kuryk
# Processing Record 1 of Set 11 | storforshei
# Processing Record 2 of Set 11 | bandarbeyla
# Processing Record 3 of Set 11 | shenkursk
# Processing Record 4 of Set 11 | sheridan
# Processing Record 5 of Set 11 | erenhot
# Processing Record 6 of Set 11 | grimma
# Processing Record 7 of Set 11 | sawang daen din
# Processing Record 8 of Set 11 | cacador
# Processing Record 9 of Set 11 | bereda
# Processing Record 10 of Set 11 | villarrobledo
# Processing Record 11 of Set 11 | nipawin
# Processing Record 12 of Set 11 | matara
# Processing Record 13 of Set 11 | high rock
# Processing Record 14 of Set 11 | markova
# Processing Record 15 of Set 11 | bonga
# Processing Record 16 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 17 of Set 11 | gainesville
# Processing Record 18 of Set 11 | valley city
# Processing Record 19 of Set 11 | mama
# Processing Record 20 of Set 11 | monrovia
# Processing Record 21 of Set 11 | tura
# Processing Record 22 of Set 11 | rosario
# Processing Record 23 of Set 11 | taranagar
# Processing Record 24 of Set 11 | rocha
# Processing Record 25 of Set 11 | kavaratti
# Processing Record 26 of Set 11 | sokolka
# Processing Record 27 of Set 11 | avera
# Processing Record 28 of Set 11 | kirkwood
# Processing Record 29 of Set 11 | port macquarie
# Processing Record 30 of Set 11 | tshikapa
# Processing Record 31 of Set 11 | imbituba
# Processing Record 32 of Set 11 | ormara
# Processing Record 33 of Set 11 | barcelos
# Processing Record 34 of Set 11 | namakkal
# Processing Record 35 of Set 11 | gweta
# Processing Record 36 of Set 11 | port lincoln
# Processing Record 37 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 11 | itarema
# Processing Record 39 of Set 11 | whitehorse
# Processing Record 40 of Set 11 | chulym
# Processing Record 41 of Set 11 | guarapari
# Processing Record 42 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 11 | nagram
# Processing Record 44 of Set 11 | tokur
# Processing Record 45 of Set 11 | berbera
# Processing Record 46 of Set 11 | south lake tahoe
# Processing Record 47 of Set 11 | kiama
# Processing Record 48 of Set 11 | artesia
# Processing Record 49 of Set 11 | gravdal
# Processing Record 50 of Set 11 | gat
# Processing Record 1 of Set 12 | talnakh
# Processing Record 2 of Set 12 | palenque
# Processing Record 3 of Set 12 | mlonggo
# Processing Record 4 of Set 12 | plouzane
# Processing Record 5 of Set 12 | port pirie
# Processing Record 6 of Set 12 | khani
# Processing Record 7 of Set 12 | nanticoke
# Processing Record 8 of Set 12 | mattru
# Processing Record 9 of Set 12 | miandrivazo
# Processing Record 10 of Set 12 | saint anthony
# Processing Record 11 of Set 12 | vostok
# Processing Record 12 of Set 12 | preili
# Processing Record 13 of Set 12 | lahaina
# Processing Record 14 of Set 12 | fiumicino
# Processing Record 15 of Set 12 | sandy bay
# Processing Record 16 of Set 12 | gimli
# Processing Record 17 of Set 12 | khasan
# Processing Record 18 of Set 12 | dvinskoy
# Processing Record 19 of Set 12 | chernyshevskiy
# Processing Record 20 of Set 12 | aklavik
# Processing Record 21 of Set 12 | vanimo
# Processing Record 22 of Set 12 | taltal
# Processing Record 23 of Set 12 | griffith
# Processing Record 24 of Set 12 | lexington park
# Processing Record 25 of Set 12 | changping
# Processing Record 26 of Set 12 | jalu
# Processing Record 27 of Set 12 | killybegs
# Processing Record 28 of Set 12 | guerrero negro
# Processing Record 29 of Set 12 | morondava
# Processing Record 30 of Set 12 | filingue
# Processing Record 31 of Set 12 | palmer
# Processing Record 32 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 12 | pedernales
# Processing Record 34 of Set 12 | fomboni
# Processing Record 35 of Set 12 | marrakesh
# Processing Record 36 of Set 12 | manokwari
# Processing Record 37 of Set 12 | vikhorevka
# Processing Record 38 of Set 12 | trabzon
# Processing Record 39 of Set 12 | sergeyevka
# Processing Record 40 of Set 12 | sisimiut
# Processing Record 41 of Set 12 | fontenay-le-comte
# Processing Record 42 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 12 | kupang
# Processing Record 44 of Set 12 | kirakira
# Processing Record 45 of Set 12 | louis trichardt
# Processing Record 46 of Set 12 | mingguang
# Processing Record 47 of Set 12 | ostrovnoy
# Processing Record 48 of Set 12 | san carlos de bariloche
# Processing Record 49 of Set 12 | crotone
# Processing Record 50 of Set 12 | bose
# Processing Record 1 of Set 13 | itoman
# Processing Record 2 of Set 13 | thanh hoa
# Processing Record 3 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 13 | fairbanks
# Processing Record 5 of Set 13 | emporia
# Processing Record 6 of Set 13 | kurilsk
# Processing Record 7 of Set 13 | listvyanskiy
# Processing Record 8 of Set 13 | dehui
# Processing Record 9 of Set 13 | solhan
# Processing Record 10 of Set 13 | pangai
# Processing Record 11 of Set 13 | hofn
# Processing Record 12 of Set 13 | ucluelet
# Processing Record 13 of Set 13 | shingu
# Processing Record 14 of Set 13 | shasta lake
# Processing Record 15 of Set 13 | kyra
# Processing Record 16 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 13 | maceio
# Processing Record 18 of Set 13 | remanso
# Processing Record 19 of Set 13 | manalurpet
# City not found. Skipping...
# Processing Record 20 of Set 13 | redcliffe
# Processing Record 21 of Set 13 | chapada dos guimaraes
# Processing Record 22 of Set 13 | bol
# Processing Record 23 of Set 13 | kailua
# Processing Record 24 of Set 13 | gamba
# Processing Record 25 of Set 13 | berlevag
# Processing Record 26 of Set 13 | lorengau
# Processing Record 27 of Set 13 | hirara
# Processing Record 28 of Set 13 | tucuman
# Processing Record 29 of Set 13 | labuhan
# Processing Record 30 of Set 13 | branistea
# Processing Record 31 of Set 13 | kathmandu
# Processing Record 32 of Set 13 | rawlins
# Processing Record 33 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 34 of Set 13 | sempeter
# City not found. Skipping...
# Processing Record 35 of Set 13 | georgiyevskoye
# Processing Record 36 of Set 13 | mendoza
# Processing Record 37 of Set 13 | rock hill
# Processing Record 38 of Set 13 | muisne
# Processing Record 39 of Set 13 | shubarkuduk
# Processing Record 40 of Set 13 | gotsu
# Processing Record 41 of Set 13 | hue
# Processing Record 42 of Set 13 | vieques
# Processing Record 43 of Set 13 | mananara
# Processing Record 44 of Set 13 | ercis
# Processing Record 45 of Set 13 | astana
# Processing Record 46 of Set 13 | raudeberg
# Processing Record 47 of Set 13 | saint-georges
# Processing Record 48 of Set 13 | parthenay
# Processing Record 49 of Set 13 | luanda
# Processing Record 50 of Set 13 | tengushevo
# Processing Record 1 of Set 14 | sumbe
# Processing Record 2 of Set 14 | tsagan aman
# Processing Record 3 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 14 | yaan
# Processing Record 5 of Set 14 | kutum
# Processing Record 6 of Set 14 | quijingue
# Processing Record 7 of Set 14 | riverton
# Processing Record 8 of Set 14 | iki-burul
# Processing Record 9 of Set 14 | biak
# Processing Record 10 of Set 14 | ampanihy
# Processing Record 11 of Set 14 | greenwood
# Processing Record 12 of Set 14 | seymchan
# Processing Record 13 of Set 14 | vylgort
# City not found. Skipping...
# Processing Record 14 of Set 14 | prieska
# Processing Record 15 of Set 14 | chardara
# Processing Record 16 of Set 14 | husavik
# Processing Record 17 of Set 14 | boa vista
# Processing Record 18 of Set 14 | linjiang
# Processing Record 19 of Set 14 | karoi
# Processing Record 20 of Set 14 | derbent
# Processing Record 21 of Set 14 | timizart
# Processing Record 22 of Set 14 | quatre cocos
# Processing Record 23 of Set 14 | santa fe
# Processing Record 24 of Set 14 | cairns
# Processing Record 25 of Set 14 | suntar
# Processing Record 26 of Set 14 | uyuni
# Processing Record 27 of Set 14 | lingao
# Processing Record 28 of Set 14 | wuda
# Processing Record 29 of Set 14 | amapa
# Processing Record 30 of Set 14 | jurm
# Processing Record 31 of Set 14 | shache
# Processing Record 32 of Set 14 | ninghai
# Processing Record 33 of Set 14 | le port
# Processing Record 34 of Set 14 | sinnamary
# Processing Record 35 of Set 14 | dakar
# Processing Record 36 of Set 14 | tecolutla
# Processing Record 37 of Set 14 | safford
# Processing Record 38 of Set 14 | kununurra
# Processing Record 39 of Set 14 | soskovo
# Processing Record 40 of Set 14 | palimbang
# Processing Record 41 of Set 14 | payo
# Processing Record 42 of Set 14 | sirnak
# Processing Record 43 of Set 14 | obernkirchen
# Processing Record 44 of Set 14 | killam
# Processing Record 45 of Set 14 | camopi
# Processing Record 46 of Set 14 | blyth
# Processing Record 47 of Set 14 | la joya
# Processing Record 48 of Set 14 | pierre
# Processing Record 49 of Set 14 | te anau
# Processing Record 50 of Set 14 | belyye berega
# Processing Record 1 of Set 15 | esna
# Processing Record 2 of Set 15 | nacozari
# Processing Record 3 of Set 15 | batemans bay
# Processing Record 4 of Set 15 | clyde river
# Processing Record 5 of Set 15 | asyut
# Processing Record 6 of Set 15 | teguise
# Processing Record 7 of Set 15 | tottori
# Processing Record 8 of Set 15 | emba
# Processing Record 9 of Set 15 | teberda
# Processing Record 10 of Set 15 | muscat
# Processing Record 11 of Set 15 | acarau
# Processing Record 12 of Set 15 | anloga
# Processing Record 13 of Set 15 | victoria
# Processing Record 14 of Set 15 | hervey bay
# Processing Record 15 of Set 15 | saint-pierre
# Processing Record 16 of Set 15 | wanning
# Processing Record 17 of Set 15 | port keats
# Processing Record 18 of Set 15 | damara
# Processing Record 19 of Set 15 | bay roberts
# Processing Record 20 of Set 15 | sotnikovo
# Processing Record 21 of Set 15 | breves
# Processing Record 22 of Set 15 | mao
# Processing Record 23 of Set 15 | tiznit
# Processing Record 24 of Set 15 | lincoln
# Processing Record 25 of Set 15 | holme
# Processing Record 26 of Set 15 | bafq
# Processing Record 27 of Set 15 | ahipara
# Processing Record 28 of Set 15 | gbadolite
# Processing Record 29 of Set 15 | alghero
# Processing Record 30 of Set 15 | pattoki
# Processing Record 31 of Set 15 | mandera
# Processing Record 32 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 15 | maningrida
# Processing Record 34 of Set 15 | oka
# Processing Record 35 of Set 15 | aswan
# Processing Record 36 of Set 15 | buena vista
# Processing Record 37 of Set 15 | thinadhoo
# Processing Record 38 of Set 15 | salinas
# Processing Record 39 of Set 15 | kaeo
# Processing Record 40 of Set 15 | grants
# Processing Record 41 of Set 15 | sibolga
# Processing Record 42 of Set 15 | bedele
# Processing Record 43 of Set 15 | kuznechnoye
# Processing Record 44 of Set 15 | himora
# City not found. Skipping...
# Processing Record 45 of Set 15 | evans
# Processing Record 46 of Set 15 | pemagatsel
# Processing Record 47 of Set 15 | oxford
# Processing Record 48 of Set 15 | mitu
# Processing Record 49 of Set 15 | wladyslawowo
# Processing Record 50 of Set 15 | canakkale
# Processing Record 1 of Set 16 | mahadday weyne
# City not found. Skipping...
# Processing Record 2 of Set 16 | vagur
# Processing Record 3 of Set 16 | lubumbashi
# Processing Record 4 of Set 16 | grenville
# Processing Record 5 of Set 16 | balykshi
# Processing Record 6 of Set 16 | contamana
# Processing Record 7 of Set 16 | evensk
# Processing Record 8 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 16 | udachnyy
# Processing Record 10 of Set 16 | waipawa
# Processing Record 11 of Set 16 | andenes
# Processing Record 12 of Set 16 | zeya
# Processing Record 13 of Set 16 | minot
# Processing Record 14 of Set 16 | yanan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Thompson      CA  55.7435  -97.8558     42.96        75          75
# 1       Ushuaia      AR -54.8000  -68.3000     44.26        81          75
# 2         Vaini      TO -21.2000 -175.2000     77.16        94          75
# 3     Grindavik      IS  63.8424  -22.4338     36.07        75          90
# 4    Georgetown      MY   5.4112  100.3354     78.73        96          40
# ..          ...     ...      ...       ...       ...       ...         ...
# 701    Udachnyy      RU  66.4167  112.4000     19.31        87         100
# 702     Waipawa      NZ -41.4122  175.5153     55.92        76           0
# 703     Andenes      NO  69.3143   16.1194     35.58        75          20
# 704        Zeya      RU  53.7500  127.2667     13.10        69          11
# 705       Minot      US  48.2325 -101.2963     52.79        53          75
#
#      Wind Speed     Current Description
# 0         13.80           broken clouds
# 1         23.02              light rain
# 2          8.05              light rain
# 3         13.80              light rain
# 4          2.30  thunderstorm with rain
# ..          ...                     ...
# 701       16.78         overcast clouds
# 702        1.72               clear sky
# 703       10.36              few clouds
# 704        3.02              few clouds
# 705        3.44           broken clouds
#
# [706 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label = "City_ID")
